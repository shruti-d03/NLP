# %%
import re
text= '''number of elon musk is 11234567890 and (999)-333-777'''
pattern='\d{10} | \(\d{3}\)-\d{3}-\d{3}'
matches= re.findall(pattern , text)
matches
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/cg/fmjm4pc94vg2ksg_7yd036780000gn/T/ipykernel_1655/2488970481.py:3: SyntaxWarning: invalid escape sequence '\d'
#   pattern='\d{10} | \(\d{3}\)-\d{3}-\d{3}'
# ['1234567890 ', ' (999)-333-777']

# %%
text = '''
Note 1 - Overview
'''
pattern = 'Note \d - ([^\n]*)'
matches = re.findall(pattern, text)
matches
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/cg/fmjm4pc94vg2ksg_7yd036780000gn/T/ipykernel_1655/3340925824.py:4: SyntaxWarning: invalid escape sequence '\d'
#   pattern = 'Note \d - ([^\n]*)'
# ['Overview']

# %%
text = '''
The gross cost of operating lease vehicles in FY2021 Q1 was $4.85 billion.
In previous quarter i.e. FY2020 Q4 it was $3 billion. 
'''

pattern = 'FY\d{4} Q[1-4]'

matches = re.findall(pattern, text)
matches
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/cg/fmjm4pc94vg2ksg_7yd036780000gn/T/ipykernel_1655/2740934438.py:6: SyntaxWarning: invalid escape sequence '\d'
#   pattern = 'FY\d{4} Q[1-4]'
# ['FY2021 Q1', 'FY2020 Q4']

# %%
text = '''
Tesla's gross cost of operating lease vehicles in FY2021 Q1 was $4.85 billion. 
In previous quarter i.e. FY2020 Q4 it was $3 billion.
'''

pattern = '\$([0-9\.]+)'
matches = re.findall(pattern, text)
matches
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\$'
# <>:6: SyntaxWarning: invalid escape sequence '\$'
# /var/folders/cg/fmjm4pc94vg2ksg_7yd036780000gn/T/ipykernel_1655/261899868.py:6: SyntaxWarning: invalid escape sequence '\$'
#   pattern = '\$([0-9\.]+)'
# ['4.85', '3']

# %%
#Extract periods and financial numbers both
text = '''
Tesla's gross cost of operating lease vehicles in FY2021 Q1 was $4.85 billion. 
In previous quarter i.e. FY2020 Q4 it was $3 billion.
'''
pattern = 'FY(\d{4} Q[1-4])[^\$]+\$([0-9\.]+)'

matches = re.findall(pattern, text)
matches
[('2021 Q1', '4.85'), ('2020 Q4', '3')]
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/cg/fmjm4pc94vg2ksg_7yd036780000gn/T/ipykernel_1655/3779320555.py:6: SyntaxWarning: invalid escape sequence '\d'
#   pattern = 'FY(\d{4} Q[1-4])[^\$]+\$([0-9\.]+)'
# [('2021 Q1', '4.85'), ('2020 Q4', '3')]

# %%
re.search
text = '''
Tesla's gross cost of operating lease vehicles in FY2021 Q1 ljh lsj a 123 was $4.85 billion. Same number for FY2020 Q4 was $8 billion
'''
pattern = 'FY(\d{4} Q[1-4])[^\$]+\$([0-9\.]+)'

matches = re.search(pattern, text)
matches
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/cg/fmjm4pc94vg2ksg_7yd036780000gn/T/ipykernel_1655/2455978859.py:5: SyntaxWarning: invalid escape sequence '\d'
#   pattern = 'FY(\d{4} Q[1-4])[^\$]+\$([0-9\.]+)'
# <re.Match object; span=(51, 84), match='FY2021 Q1 ljh lsj a 123 was $4.85'>

# %%
matches.groups()
# Out:
# ('2021 Q1', '4.85')
