# %% [markdown]
# ## Stemming in NLTK

# %%
import nltk
import spacy

# %%
 # Import PorterStemmer from NLTK library
from nltk.stem import PorterStemmer

# Create a stemmer object
stemmer = PorterStemmer()

# List of words to stem
words = ["eating", "eats", "eat", "ate", "adjustable", "rafting", "ability", "meeting"]

# Loop through each word and print original word with its stemmed version
for word in words:
    print(word, "|", stemmer.stem(word))
# Out:
# eating | eat
# eats | eat
# eat | eat
# ate | ate
# adjustable | adjust
# rafting | raft
# ability | abil
# meeting | meet

# %% [markdown]
# ## Lemmatization in Spacy

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

doc = nlp("Mando talked for 3 hours although talking isn't his thing")
doc = nlp("eating eats eat ate adjustable rafting ability meeting better")
for token in doc:
    print(token, " | ", token.lemma_)
# Out:
# eating  |  eat
# eats  |  eat
# eat  |  eat
# ate  |  eat
# adjustable  |  adjustable
# rafting  |  raft
# ability  |  ability
# meeting  |  meet
# better  |  well

# %% [markdown]
# ## Customizing lemmatizer

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
# Get the attribute_ruler component from the pipeline
ar = nlp.get_pipe('attribute_ruler')

# Add custom rules:
# If token text is "Bro" OR "Brah" → set its lemma to "Brother"
ar.add([[{"TEXT": "Bro"}], [{"TEXT": "Brah"}]], {"LEMMA": "Brother"})

# Process the sentence
doc = nlp("Bro, you wanna go? Brah, don't say no! I am exhausted")

# Print each token with its lemma (base/dictionary form)
for token in doc:
# Out:
# Bro | Brother
# , | ,
# you | you
# wanna | wanna
# go | go
# ? | ?
# Brah | Brother
# , | ,
# do | do
# n't | not
# say | say
# no | no
# ! | !
# I | I
# am | be
# exhausted | exhaust
