# %%
import spacy
nlp = spacy.blank("en")  # create a blank English language object
doc = nlp("Dr.Strange loves pav bhaji of mumbai. Hulk loves chaat of Delhi")
for token in doc:#you will directly get word tokenization 
    print(token)
# Out:
# Dr.
# Strange
# loves
# pav
# bhaji
# of
# mumbai
# .
# Hulk
# loves
# chaat
# of
# Delhi

# %%
doc[0]
# Out:
# Dr.

# %%
doc[-1]
# Out:
# Delhi

# %%
import spacy

nlp = spacy.blank("en")
doc = nlp("Dr.Strange loves pav bhaji of mumbai. Hulk loves chaat of Delhi")

for token in doc:
    print(token.text, "-->  index:", token.i)
# Out:
# Dr. -->  index: 0
# Strange -->  index: 1
# loves -->  index: 2
# pav -->  index: 3
# bhaji -->  index: 4
# of -->  index: 5
# mumbai -->  index: 6
# . -->  index: 7
# Hulk -->  index: 8
# loves -->  index: 9
# chaat -->  index: 10
# of -->  index: 11
# Delhi -->  index: 12

# %%
import spacy

nlp = spacy.blank("en")
doc = nlp("Dr.Strange loves mumbai.")

print("--- token.text ---")
for token in doc:
    print(token.text)
# Out:
# --- token.text ---
# Dr.
# Strange
# loves
# mumbai
# .

# %%
doc = nlp("Tony gave two $ to Peter.")

# %%
token0 = doc[0]
token0
# Out:
# Tony

# %%
token0.is_alpha
# Out:
# True

# %%
token0.like_num
# Out:
# False

# %%
token2 = doc[2]
token2
# Out:
# two

# %%
token2.like_num
# Out:
# True

# %%
token3 = doc[3]
token3
# Out:
# $

# %%
token3.is_currency
# Out:
# True

# %%
for token in doc:
    print(token, "==>", "index: ", token.i, "is_alpha:", token.is_alpha, #is alphabet 
          "is_punct:", token.is_punct, #for punctuation
          "like_num:", token.like_num,#is number or not
          "is_currency:", token.is_currency,#is currency or not
         )
# Out:
# Tony ==> index:  0 is_alpha: True is_punct: False like_num: False is_currency: False
# gave ==> index:  1 is_alpha: True is_punct: False like_num: False is_currency: False
# two ==> index:  2 is_alpha: True is_punct: False like_num: True is_currency: False
# $ ==> index:  3 is_alpha: False is_punct: False like_num: False is_currency: True
# to ==> index:  4 is_alpha: True is_punct: False like_num: False is_currency: False
# Peter ==> index:  5 is_alpha: True is_punct: False like_num: False is_currency: False
# . ==> index:  6 is_alpha: False is_punct: True like_num: False is_currency: False

# %%
from spacy.symbols import ORTH

nlp = spacy.blank("en")
doc = nlp("gimme double cheese extra large healthy pizza")
tokens = [token.text for token in doc]#MOVE FOR LOOP IN TOKEN 
tokens
# Out:
# ['gimme', 'double', 'cheese', 'extra', 'large', 'healthy', 'pizza']

# %%
nlp.tokenizer.add_special_case("gimme", [
    {ORTH: "gim"},
    {ORTH: "me"},
])
doc = nlp("gimme double cheese extra large healthy pizza")
tokens = [token.text for token in doc]
tokens
# Out:
# ['gim', 'me', 'double', 'cheese', 'extra', 'large', 'healthy', 'pizza']

# %%
doc = nlp("Dr. Strange loves pav bhaji of mumbai. Hulk loves chat of delhi")
for sentence in doc.sents:
    print(sentence)

    #pipeline is blank
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 doc = nlp("Dr. Strange loves pav bhaji of mumbai. Hulk loves chat of delhi")
# ----> 2 for sentence in doc.sents:
#       3     print(sentence)
#
# File ~/miniconda3/lib/python3.13/site-packages/spacy/tokens/doc.pyx:926, in sents()
#
# ValueError: [E030] Sentence boundaries unset. You can add the 'sentencizer' component to the pipeline with: `nlp.add_pipe('sentencizer')`. Alternatively, add the dependency parser or sentence recognizer, or set sentence boundaries by setting `doc[i].is_sent_start`.

# %%
nlp.pipeline
# Out:
# []

# %%
nlp.add_pipe('sentencizer')#add component in pipeline

# %%
doc = nlp("Dr. Strange loves pav bhaji of mumbai. Hulk loves chat of delhi")
for sentence in doc.sents:
    print(sentence)
# Out:
# Dr. Strange loves pav bhaji of mumbai.
# Hulk loves chat of delhi

# %%
nlp.pipeline
# Out:
# [('sentencizer', <spacy.pipeline.sentencizer.Sentencizer at 0x1079a33d0>)]
